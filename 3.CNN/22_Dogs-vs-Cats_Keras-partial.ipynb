# %% [markdown]
# # Dogs vs Cats v2
# ## Kaggle Dataset의 일부를 이용한 개, 고양이 구분
# ### Dog Image: 1,111개, Cat Image: 1,111개, 총 2,222개
# ### One-hot-encoding --> Logistic Regression
# ### Data shuffling
# ### 출처: [pontoregende GitHub](https://github.com/pontorezende/Dogs-vs-Cats-Redux-with-CNN)

# %%
import numpy as np
from glob import glob
import cv2, os, random
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing import image
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.layers import Dense, Flatten, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

# %%
path='dogs-vs-cats/train/'

# %%
## used for resize and in our model
ROW, COL = 96, 96

dogs, cats = [], []
y_dogs, y_cats = [], []

# %%
dog_path = os.path.join(path, 'dog.5*')
len(glob(dog_path))
# Out:
# 1111

# %%
## Load some our dog images (1,111 개 이미지)
dog_path = os.path.join(path, 'dog.5*')
for dog_img in glob(dog_path):
    dog = cv2.imread(dog_img)
    dog = cv2.cvtColor(dog, cv2.COLOR_BGR2GRAY)
    dog = cv2.resize(dog, (ROW, COL))
    dog = image.img_to_array(dog)
    dogs.append(dog)

# %%
## Load some our cat images (1,111 개 이미지)
cat_path = os.path.join(path, 'cat.5*')
for cat_img in glob(cat_path):
    cat = cv2.imread(cat_img)
    cat = cv2.cvtColor(cat, cv2.COLOR_BGR2GRAY)
    cat = cv2.resize(cat, (ROW, COL))
    cat = image.img_to_array(cat)
    cats.append(cat)

# %%
classes = ['dog', 'cat']

# %%
plt.figure(figsize=(12,8))    
for i in range(5):
    plt.subplot(1, 5, i+1)
    img = image.array_to_img(random.choice(dogs))
    plt.imshow(img, cmap=plt.get_cmap('gray'))

    plt.axis('off')
    plt.title('It should be a {}.'.format(classes[0]))        
plt.show()

# %%
plt.figure(figsize=(12,8))
for i in range(5):
    plt.subplot(1, 5, i+1)
    img = image.array_to_img(random.choice(cats))
    plt.imshow(img, cmap=plt.get_cmap('gray'))

    plt.axis('off')
    plt.title('It should be a {}.'.format(classes[1]))
plt.show()

# %%
## just change the labels for 0 and  1
y_dogs = [1 for item in enumerate(dogs)]
y_cats = [0 for item in enumerate(cats)]

# %%
## converting everything to Numpy array to fit in our model
## them creating a X and target file like we used to see
## in Machine and Deep Learning models
dogs = np.asarray(dogs).astype('float32') / 255
cats = np.asarray(cats).astype('float32') / 255
y_dogs = np.asarray(y_dogs).astype('int32')
y_cats = np.asarray(y_cats).astype('int32')

# %%
X_train = np.concatenate((dogs,cats), axis=0)
y_train = np.concatenate((y_dogs, y_cats), axis=0)

# %%
len(X_train)
# Out:
# 2222

# %%
X_train.shape
# Out:
# (2222, 96, 96, 1)

# %%
y_train.shape
# Out:
# (2222,)

# %% [markdown]
# ### Test set (dog.12, cat.12) 만들기

# %%
dogs, cats = [], []
y_dogs, y_cats = [], []

# %%
dog_path = os.path.join(path, 'dog.12*')
len(glob(dog_path))
# Out:
# 611

# %%
cat_path = os.path.join(path, 'cat.12*')
len(glob(cat_path))
# Out:
# 611

# %%
## Load some our dog images (611 개 이미지)
dog_path = os.path.join(path, 'dog.12*')
for dog_img in glob(dog_path):
    dog = cv2.imread(dog_img)
    dog = cv2.cvtColor(dog, cv2.COLOR_BGR2GRAY)
    dog = cv2.resize(dog, (ROW, COL))
    dog = image.img_to_array(dog)
    dogs.append(dog)

# %%
## Load some our cat images (611 개 이미지)
cat_path = os.path.join(path, 'cat.12*')
for cat_img in glob(cat_path):
    cat = cv2.imread(cat_img)
    cat = cv2.cvtColor(cat, cv2.COLOR_BGR2GRAY)
    cat = cv2.resize(cat, (ROW, COL))
    cat = image.img_to_array(cat)
    cats.append(cat)

# %%
y_dogs = [1 for item in enumerate(dogs)]
y_cats = [0 for item in enumerate(cats)]

# %%
dogs = np.asarray(dogs).astype('float32') / 255
cats = np.asarray(cats).astype('float32') / 255
y_dogs = np.asarray(y_dogs).astype('int32')
y_cats = np.asarray(y_cats).astype('int32')

# %%
dogs.shape
# Out:
# (611, 96, 96, 1)

# %%
X_test = np.concatenate((dogs,cats), axis=0)
y_test = np.concatenate((y_dogs, y_cats), axis=0)

# %%
len(X_test)
# Out:
# 1222

# %%
X_test.shape
# Out:
# (1222, 96, 96, 1)

# %%
y_test.shape
# Out:
# (1222,)

# %%
## Here is our model as a CNN
model = Sequential([
    Conv2D(32, (3,3), padding='same', input_shape=(ROW, COL, 1), 
           activation='relu'),
    Conv2D(32, (3,3), padding='same', activation='relu'),
    MaxPooling2D(pool_size=(2,2)),
    Dropout(.25),
    Conv2D(64, (3,3), padding='same', activation='relu'),
    Conv2D(64, (3,3), padding='same', activation='relu'),
    MaxPooling2D(pool_size=(2,2)),
    Dropout(.25),
    Flatten(),
    Dense(512, activation='relu'),
    Dropout(.5),
    Dense(1, activation='sigmoid')
])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 96, 96, 32)        320
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 96, 96, 32)        9248
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 48, 48, 32)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 48, 48, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 48, 48, 64)        18496
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 48, 48, 64)        36928
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 24, 24, 64)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 24, 24, 64)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 36864)             0
# _________________________________________________________________
# dense (Dense)                (None, 512)               18874880
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 513
# =================================================================
# Total params: 18,940,385
# Trainable params: 18,940,385
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='binary_crossentropy', 
              optimizer=Adam(), metrics=['accuracy'])

# %%
## to save checkpoint to use later
modelpath = "model/dogs_vs_cats-cnn-{epoch:02d}-{val_loss:.4f}.hdf5"
checkpointer = ModelCheckpoint(filepath=modelpath, monitor='val_loss', 
                               verbose=1, save_best_only=True)
early_stopping_callback = EarlyStopping(monitor='val_loss', patience=10)

# %% [markdown]
# ### 모델 학습

# %%
model.fit(X_train, y_train, batch_size=32, epochs=40, validation_split=0.2, shuffle=True,
          callbacks=[checkpointer, early_stopping_callback])
# Out:
# Train on 1777 samples, validate on 445 samples
# Epoch 1/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.7362 - accuracy: 0.6153
# Epoch 00001: val_loss improved from inf to 0.91107, saving model to model/dogs_vs_cats-cnn-01-0.9111.hdf5
# 1777/1777 [==============================] - 30s 17ms/sample - loss: 0.7355 - accuracy: 0.6156 - val_loss: 0.9111 - val_accuracy: 0.0000e+00
# Epoch 2/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.6633 - accuracy: 0.6244
# Epoch 00002: val_loss improved from 0.91107 to 0.90698, saving model to model/dogs_vs_cats-cnn-02-0.9070.hdf5
# 1777/1777 [==============================] - 28s 16ms/sample - loss: 0.6629 - accuracy: 0.6252 - val_loss: 0.9070 - val_accuracy: 0.0000e+00
# Epoch 3/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.6514 - accuracy: 0.6364
# Epoch 00003: val_loss improved from 0.90698 to 0.84530, saving model to model/dogs_vs_cats-cnn-03-0.8453.hdf5
# 1777/1777 [==============================] - 28s 16ms/sample - loss: 0.6519 - accuracy: 0.6353 - val_loss: 0.8453 - val_accuracy: 0.0921
# Epoch 4/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.6390 - accuracy: 0.6511
# Epoch 00004: val_loss did not improve from 0.84530
# 1777/1777 [==============================] - 27s 15ms/sample - loss: 0.6383 - accuracy: 0.6517 - val_loss: 0.9659 - val_accuracy: 0.1865
# Epoch 5/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.6248 - accuracy: 0.6614
# Epoch 00005: val_loss improved from 0.84530 to 0.79432, saving model to model/dogs_vs_cats-cnn-05-0.7943.hdf5
# 1777/1777 [==============================] - 28s 16ms/sample - loss: 0.6250 - accuracy: 0.6601 - val_loss: 0.7943 - val_accuracy: 0.2180
# Epoch 6/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.6275 - accuracy: 0.6557
# Epoch 00006: val_loss improved from 0.79432 to 0.74216, saving model to model/dogs_vs_cats-cnn-06-0.7422.hdf5
# 1777/1777 [==============================] - 28s 16ms/sample - loss: 0.6269 - accuracy: 0.6579 - val_loss: 0.7422 - val_accuracy: 0.2607
# Epoch 7/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.6196 - accuracy: 0.6687
# Epoch 00007: val_loss did not improve from 0.74216
# 1777/1777 [==============================] - 27s 15ms/sample - loss: 0.6199 - accuracy: 0.6680 - val_loss: 0.9054 - val_accuracy: 0.1955
# Epoch 8/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.5995 - accuracy: 0.6818
# Epoch 00008: val_loss did not improve from 0.74216
# 1777/1777 [==============================] - 27s 15ms/sample - loss: 0.5996 - accuracy: 0.6826 - val_loss: 0.8590 - val_accuracy: 0.1708
# Epoch 9/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.5845 - accuracy: 0.6852
# Epoch 00009: val_loss did not improve from 0.74216
# 1777/1777 [==============================] - 26s 15ms/sample - loss: 0.5833 - accuracy: 0.6860 - val_loss: 0.9918 - val_accuracy: 0.2360
# Epoch 10/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.5646 - accuracy: 0.7011
# Epoch 00010: val_loss did not improve from 0.74216
# 1777/1777 [==============================] - 27s 15ms/sample - loss: 0.5639 - accuracy: 0.7012 - val_loss: 0.9047 - val_accuracy: 0.1955
# Epoch 11/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.5295 - accuracy: 0.7278
# Epoch 00011: val_loss did not improve from 0.74216
# 1777/1777 [==============================] - 27s 15ms/sample - loss: 0.5297 - accuracy: 0.7288 - val_loss: 0.7959 - val_accuracy: 0.4135
# Epoch 12/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.4969 - accuracy: 0.7534
# Epoch 00012: val_loss improved from 0.74216 to 0.73665, saving model to model/dogs_vs_cats-cnn-12-0.7367.hdf5
# 1777/1777 [==============================] - 29s 16ms/sample - loss: 0.4967 - accuracy: 0.7541 - val_loss: 0.7367 - val_accuracy: 0.5101
# Epoch 13/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.4349 - accuracy: 0.7909
# Epoch 00013: val_loss did not improve from 0.73665
# 1777/1777 [==============================] - 27s 15ms/sample - loss: 0.4349 - accuracy: 0.7912 - val_loss: 1.0178 - val_accuracy: 0.4045
# Epoch 14/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.3919 - accuracy: 0.8267
# Epoch 00014: val_loss did not improve from 0.73665
# 1777/1777 [==============================] - 27s 15ms/sample - loss: 0.3922 - accuracy: 0.8267 - val_loss: 1.0203 - val_accuracy: 0.4674
# Epoch 15/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.3156 - accuracy: 0.8551
# Epoch 00015: val_loss did not improve from 0.73665
# 1777/1777 [==============================] - 27s 15ms/sample - loss: 0.3188 - accuracy: 0.8537 - val_loss: 0.9994 - val_accuracy: 0.5775
# Epoch 16/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.2530 - accuracy: 0.8960
# Epoch 00016: val_loss did not improve from 0.73665
# 1777/1777 [==============================] - 28s 16ms/sample - loss: 0.2528 - accuracy: 0.8959 - val_loss: 0.9805 - val_accuracy: 0.5708
# Epoch 17/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.1899 - accuracy: 0.9312
# Epoch 00017: val_loss did not improve from 0.73665
# 1777/1777 [==============================] - 27s 15ms/sample - loss: 0.1917 - accuracy: 0.9297 - val_loss: 0.9919 - val_accuracy: 0.6202
# Epoch 18/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.1359 - accuracy: 0.9449
# Epoch 00018: val_loss did not improve from 0.73665
# 1777/1777 [==============================] - 28s 16ms/sample - loss: 0.1351 - accuracy: 0.9454 - val_loss: 1.1864 - val_accuracy: 0.6022
# Epoch 19/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.1196 - accuracy: 0.9608
# Epoch 00019: val_loss did not improve from 0.73665
# 1777/1777 [==============================] - 27s 15ms/sample - loss: 0.1202 - accuracy: 0.9606 - val_loss: 1.6658 - val_accuracy: 0.5393
# Epoch 20/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.0918 - accuracy: 0.9608
# Epoch 00020: val_loss did not improve from 0.73665
# 1777/1777 [==============================] - 27s 15ms/sample - loss: 0.0914 - accuracy: 0.9612 - val_loss: 2.1472 - val_accuracy: 0.5124
# Epoch 21/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.0984 - accuracy: 0.9676
# Epoch 00021: val_loss did not improve from 0.73665
# 1777/1777 [==============================] - 27s 15ms/sample - loss: 0.0985 - accuracy: 0.9674 - val_loss: 1.4994 - val_accuracy: 0.5865
# Epoch 22/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.0645 - accuracy: 0.9790
# Epoch 00022: val_loss did not improve from 0.73665
# 1777/1777 [==============================] - 29s 16ms/sample - loss: 0.0640 - accuracy: 0.9792 - val_loss: 1.4682 - val_accuracy: 0.6180

# %%
from tensorflow.keras.models import load_model
del model
model = load_model('model/dogs_vs_cats-cnn-12-0.7367.hdf5')

# %%
scores = model.evaluate(X_test, y_test, verbose=2)
print('MODEL ACCURACY: %.5f' % scores[1])
# Out:
# 1222/1222 - 6s - loss: 0.6568 - accuracy: 0.6285
# MODEL ACCURACY: 0.62848
